# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши

# %% [markdown]
# - Студент : Зимасс Марина Геннадьевна
# - Дата : 31.12.2025

# %% [markdown]
# ## **Цели и задачи проекта**
# Целью проекта является составление профиля лояльного пользователя Яндекс.Афиши для дальшейшего улучшения работы сервиса и привлечения новых пользователей с удержанием уже зарегистрированных.
# Задачами проекта являются:
# - составления профиля пользователя;
# - выделения ряда особенностей лояльных клиентов сервиса;
# - установление взаимоствязи между активностью клиента и различными показателями его действий и характеристик;
# - предоставление рекомендаций, основанных на изучении данных.

# %% [markdown]
# ## Описание данных
#
# - user_id — уникальный идентификатор пользователя, совершившего заказ;
# - device_type_canonical — тип устройства, с которого был оформлен заказ;
# - order_id — уникальный идентификатор заказа;
# - order_dt — дата создания заказа;
# - order_ts — дата и время создания заказа;
# - currency_code — валюта оплаты;
# - revenue — выручка от заказа;
# - tickets_count — количество купленных билетов;
# - days_since_prev — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - event_id — уникальный идентификатор мероприятия;
# - service_name — название билетного оператора;
# - event_type_main — основной тип мероприятия;
# - region_name — название региона, в котором прошло мероприятие;
# - city_name — название города, в котором прошло мероприятие.

# %% [markdown]
# # **Этапы выполнения проекта**
#
# ### 1) Загрузка данных
# ### 2) Предобработка данных
# ### 3) Создание профиля пользователя
# ### 4) Исследовательский анализ данных
# ### 5) Общий вывод и рекомендации

# %% [markdown]
# ### ***1) Загрузка данных***

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (2.0.45)
# Requirement already satisfied: greenlet>=1 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from sqlalchemy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from sqlalchemy) (4.12.2)

# %%
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (2.9.11)

# %%
# !pip install phik
# Out:
# Requirement already satisfied: phik in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (0.12.5)
# Requirement already satisfied: numpy>=1.18.0 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from phik) (2.4.0)
# Requirement already satisfied: scipy>=1.5.2 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from phik) (1.16.3)
# Requirement already satisfied: pandas>=0.25.1 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from phik) (2.3.3)
# Requirement already satisfied: matplotlib>=2.2.3 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from phik) (3.10.8)
# Requirement already satisfied: joblib>=0.14.1 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from phik) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=2.2.3->phik) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=2.2.3->phik) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=2.2.3->phik) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=2.2.3->phik) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=2.2.3->phik) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=2.2.3->phik) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=2.2.3->phik) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=2.2.3->phik) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pandas>=0.25.1->phik) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pandas>=0.25.1->phik) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.17.0)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from seaborn) (2.4.0)
# Requirement already satisfied: pandas>=1.2 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/tatjana/opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from phik import phik_matrix
from sqlalchemy import create_engine

# %%
db_config = {'user': 'praktikum_student', # имя пользователя
             'pwd': 'Sdf4$2;d-d30pp', # пароль
             'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
             'port': 6432, # порт подключения
             'db': 'data-analyst-afisha' # название базы данных
             }

# %%
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'],
    db_config['pwd'],
    db_config['host'],
    db_config['port'],
    db_config['db'],
)

# %%
engine = create_engine(connection_string)

# %%
query = '''
SELECT p.user_id,
       p.device_type_canonical, 
       p.order_id, 
       p.created_dt_msk AS order_dt, 
       p.created_ts_msk AS order_ts, 
       p.currency_code, 
       p.revenue, 
       p.tickets_count, 
       p.created_dt_msk::date - LAG(p.created_dt_msk::date) OVER (PARTITION BY user_id ORDER BY p.created_dt_msk::date) AS days_since_prev,
       e.event_id,
       e.event_name_code AS event_name, 
       p.service_name, 
       e.event_type_main, 
       r.region_name, 
       c.city_name 
FROM afisha.purchases AS p 
LEFT JOIN afisha.events AS e USING (event_id)
LEFT JOIN afisha.city AS c USING (city_id)
LEFT JOIN afisha.regions AS r USING (region_id) 
WHERE (p.device_type_canonical = 'desktop' OR p.device_type_canonical = 'mobile') AND (e.event_type_main != 'фильм')
ORDER BY user_id;
'''

# %%
df = pd.read_sql_query(query, con=engine)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  service_name           290611 non-null  object
#  12  event_type_main        290611 non-null  object
#  13  region_name            290611 non-null  object
#  14  city_name              290611 non-null  object
# dtypes: datetime64[ns](2), float64(2), int64(3), object(8)
# memory usage: 33.3+ MB

# %%
df.head()
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name        service_name  \
# 0    169230  f0f7b271-04eb-4af6-bcb8-8f05cf46d6ad        Край билетов
# 1    237325  40efeb04-81b7-4135-b41f-708ff00cc64c           Мой билет
# 2    578454  01f3fb7b-ed07-4f94-b1d3-9a2e1ee5a8ca         За билетом!
# 3    387271  2f638715-8844-466c-b43f-378a627c419f         Лови билет!
# 4    509453  10d805d3-9809-4d8a-834e-225b7d03f95d  Билеты без проблем
#
#   event_type_main           region_name    city_name
# 0           театр    Каменевский регион   Глиногорск
# 1        выставки    Каменевский регион   Глиногорск
# 2          другое    Каменевский регион   Глиногорск
# 3          другое  Североярская область       Озёрск
# 4         стендап      Озернинский край  Родниковецк

# %% [markdown]
# В ходе первичного ознакомления с данными было установлено следующее:
# - составленный запрос позволил получить датафрейм с данными, необходимыми для дальнейшего анализа;
# - типы данных соответствуют содержащейся в таблице информации и не нуждаются в корректировке;
# - пропуски зафиксированы только в столбце **days_since_prev**, что не является ошибкой данных (поскольку столбец был создан в процессе выгрузки данных и изначально не являлся элементом таблиц). Наличие пропусков по данныму столбцу указывает на то, что пользователи воспользовались услугами Яндекс.Афиши один раз.

# %% [markdown]
# ### ***2) Предобработка данных***

# %%
df_tenge = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')
print (df_tenge)
# Out:
#            data  nominal     curs  cdx
# 0    2024-01-10      100  19.9391  kzt
# 1    2024-01-11      100  19.7255  kzt
# 2    2024-01-12      100  19.5839  kzt
# 3    2024-01-13      100  19.4501  kzt
# 4    2024-01-14      100  19.4501  kzt
# ..          ...      ...      ...  ...
# 352  2024-12-27      100  19.2705  kzt
# 353  2024-12-28      100  19.5105  kzt
# 354  2024-12-29      100  19.4860  kzt
# 355  2024-12-30      100  19.4860  kzt
# 356  2024-12-31      100  19.4860  kzt
#
# [357 rows x 4 columns]

# %%
df_tenge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    object
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 11.3+ KB

# %%
df_tenge['data'] = pd.to_datetime(df_tenge['data'])
df_tenge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    datetime64[ns]
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 11.3+ KB

# %%
df = pd.merge(df, df_tenge, left_on = 'order_dt', right_on = 'data', how='left')
def into_rub (row):
    if row['currency_code'] == 'kzt':
        return row['revenue'] / row['nominal'] * row['curs']
    else:
        return row['revenue']
df['revenue_rub'] = df.apply(into_rub, axis=1)
df = df.drop(columns=df_tenge.columns)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  service_name           290611 non-null  object
#  12  event_type_main        290611 non-null  object
#  13  region_name            290611 non-null  object
#  14  city_name              290611 non-null  object
#  15  revenue_rub            290611 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(8)
# memory usage: 35.5+ MB
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name        service_name  \
# 0    169230  f0f7b271-04eb-4af6-bcb8-8f05cf46d6ad        Край билетов
# 1    237325  40efeb04-81b7-4135-b41f-708ff00cc64c           Мой билет
# 2    578454  01f3fb7b-ed07-4f94-b1d3-9a2e1ee5a8ca         За билетом!
# 3    387271  2f638715-8844-466c-b43f-378a627c419f         Лови билет!
# 4    509453  10d805d3-9809-4d8a-834e-225b7d03f95d  Билеты без проблем
#
#   event_type_main           region_name    city_name  revenue_rub
# 0           театр    Каменевский регион   Глиногорск      1521.94
# 1        выставки    Каменевский регион   Глиногорск       289.45
# 2          другое    Каменевский регион   Глиногорск      1258.57
# 3          другое  Североярская область       Озёрск         8.49
# 4         стендап      Озернинский край  Родниковецк      1390.41

# %% [markdown]
# В исходный датафрейм добавлен новый столбец revenue_rub, отражающий данные об обплате в российских рублях.

# %%
def downcast (df):
    float_cols = [c for c in df if df[c].dtype == 'float64']
    int_cols = [c for c in df if df[c].dtype in ['int64', 'int32', 'int16', 'int8']]
    
    for c in float_cols:
        df[c] = pd.to_numeric(df[c], downcast='float')
    for c in int_cols:
        df[c] = pd.to_numeric(df[c], downcast = 'integer')
    return df
df = downcast(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int32
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int8
#  8   days_since_prev        268678 non-null  float32
#  9   event_id               290611 non-null  int32
#  10  event_name             290611 non-null  object
#  11  service_name           290611 non-null  object
#  12  event_type_main        290611 non-null  object
#  13  region_name            290611 non-null  object
#  14  city_name              290611 non-null  object
#  15  revenue_rub            290611 non-null  float64
# dtypes: datetime64[ns](2), float32(1), float64(2), int32(2), int8(1), object(8)
# memory usage: 30.2+ MB

# %%
nominal_columns = [col for col in df.columns if df[col].dtype == 'object']
categories_dict = {}
for col in nominal_columns:
    categories_dict[col] = df[col].dropna().unique()
print(categories_dict)
# Out:
# {'user_id': array(['0002849b70a3ce2', '0005ca5e93f2cf4', '000898990054619', ...,
#        'fffcd3dde79eb2c', 'fffeeb3c120cf0b', 'ffff00725179321'],
#       shape=(21933,), dtype=object), 'device_type_canonical': array(['mobile', 'desktop'], dtype=object), 'currency_code': array(['rub', 'kzt'], dtype=object), 'event_name': array(['f0f7b271-04eb-4af6-bcb8-8f05cf46d6ad',
#        '40efeb04-81b7-4135-b41f-708ff00cc64c',
#        '01f3fb7b-ed07-4f94-b1d3-9a2e1ee5a8ca', ...,
#        'cf71bf2b-8e5c-47e0-a0f3-c2d4910c4677',
#        'f17a01b7-3cd3-4cd1-919c-3459bd074886',
#        '0fd6df8e-49e5-4337-954d-5a4606b1b899'],
#       shape=(15248,), dtype=object), 'service_name': array(['Край билетов', 'Мой билет', 'За билетом!', 'Лови билет!',
#        'Билеты без проблем', 'Облачко', 'Лучшие билеты', 'Прачечная',
#        'Быстробилет', 'Дом культуры', 'Весь в билетах', 'Билеты в руки',
#        'Тебе билет!', 'Show_ticket', 'Городской дом культуры', 'Яблоко',
#        'Билет по телефону', 'Выступления.ру', 'Росбилет',
#        'Шоу начинается!', 'Мир касс', 'Восьмёрка', 'Телебилет',
#        'Crazy ticket!', 'Реестр', 'Быстрый кассир', 'КарандашРУ',
#        'Радио ticket', 'Дырокол', 'Вперёд!', 'Кино билет', 'Цвет и билет',
#        'Зе Бест!', 'Тех билет', 'Лимоны', 'Билеты в интернете'],
#       dtype=object), 'event_type_main': array(['театр', 'выставки', 'другое', 'стендап', 'концерты', 'спорт',
#        'ёлки'], dtype=object), 'region_name': array(['Каменевский регион', 'Североярская область', 'Озернинский край',
#        'Лугоградская область', 'Поленовский край', 'Широковская область',
#        'Медовская область', 'Златопольский округ', 'Малиновоярский округ',
#        'Яблоневская область', 'Ветренский регион', 'Боровлянский край',
#        'Крутоводская область', 'Ягодиновская область',
#        'Серебряноярский округ', 'Лесодальний край', 'Верхоречная область',
#        'Горицветская область', 'Речиновская область', 'Травиницкий округ',
#        'Сосновская область', 'Серебринская область', 'Травяная область',
#        'Каменноярский край', 'Солнечноземская область',
#        'Светополянский округ', 'Заречная область', 'Ручейковский край',
#        'Глиногорская область', 'Тепляковская область',
#        'Каменноозёрный край', 'Солнечнореченская область',
#        'Зоринский регион', 'Берёзовская область', 'Лесостепной край',
#        'Малиновая область', 'Синегорский регион', 'Луговая область',
#        'Шанырский регион', 'Каменополянский округ', 'Речицкая область',
#        'Горностепной регион', 'Речицкий регион', 'Золотоключевской край',
#        'Лесоярская область', 'Зеленоградский округ',
#        'Миропольская область', 'Дальнеземская область',
#        'Озернопольская область', 'Берестовский округ',
#        'Ключеводский округ', 'Нежинская область', 'Дальнезорский край',
#        'Вишнёвский край', 'Каменичская область', 'Голубевский округ',
#        'Тихогорская область', 'Крутоводский регион',
#        'Чистогорская область', 'Североозёрский округ', 'Тихолесский край',
#        'Кристальная область', 'Горноземский регион',
#        'Радужнопольский край', 'Белоярская область', 'Островная область',
#        'Тихореченская область', 'Кристаловская область',
#        'Яснопольский округ', 'Островогорский округ',
#        'Радужногорская область', 'Дубравная область', 'Залесский край',
#        'Североключевской округ', 'Верховинская область',
#        'Светолесский край', 'Сосноводолинская область',
#        'Верхозёрский край', 'Лесноярский край', 'Теплоозёрский округ',
#        'Лесополянская область'], dtype=object), 'city_name': array(['Глиногорск', 'Озёрск', 'Родниковецк', 'Кристалевск',
#        'Дальнозолотск', 'Радужнополье', 'Радужсвет', 'Кумсай',
#        'Верховино', 'Светополье', 'Кокжар', 'Каменский', 'Лесоярич',
#        'Никольянов', 'Речинцево', 'Лесозолотск', 'Дальнозерск',
#        'Серебрянка', 'Островецк', 'Родниковец', 'Дальнесветск',
#        'Луговаярово', 'Ягодиновка', 'Дальнополин', 'Солчелуг', 'Озёрчане',
#        'Серебровино', 'Лесоярово', 'Глинополье', 'Глиноград',
#        'Дальнесветин', 'Северополье', 'Теплоозеро', 'Горнодолинск',
#        'Ордакент', 'Озёрово', 'Луговинск', 'Лугоград', 'Златопольск',
#        'Крутовинск', 'Сарыжар', 'Сосновечин', 'Тихоярск', 'Яблонецк',
#        'Жаркентай', 'Широковка', 'Синеводов', 'Синеводск', 'Тихосветск',
#        'Радужанов', 'Каменосветск', 'Глиногорь', 'Родниковск',
#        'Травогород', 'Глинянск', 'Радужинск', 'Поляногорье',
#        'Дальнолесье', 'Ручейник', 'Ключеград', 'Ключеводск', 'Поленовино',
#        'Речичанск', 'Ключевополье', 'Шаныртау', 'Дальнесоснов', 'Ордасай',
#        'Теплоозёрск', 'Чистогорье', 'Островярово', 'Ручейный', 'Ягодинск',
#        'Поленоозёрово', 'Акбасты', 'Медовино', 'Каменёвка', 'Рощино',
#        'Солнечнёвка', 'Верхозолотск', 'Боровлянск', 'Лугиново',
#        'Сосноград', 'Радужнояр', 'Кенесар', 'Островенск', 'Горнополец',
#        'Яблоновец', 'Вишнёво', 'Ясногородин', 'Нежинск', 'Малиноворск',
#        'Леснойск', 'Озёриново', 'Островополь', 'Тихоречка', 'Поленояр',
#        'Ручьевино', 'Травяниново', 'Кристаловец', 'Буркиттау',
#        'Ручейковск', 'Песковино', 'Горнополье', 'Зоревец', 'Акбастау',
#        'Заречиновка', 'Сосновогорец', 'Лесоводск', 'Лесочистка',
#        'Каменевовск', 'Сарытау', 'Малиновец', 'Речевинец', 'Кристалинск',
#        'Верхоозёров', 'Травяночистск', 'Байкуль', 'Светоярчик',
#        'Зориново', 'Лесореченск', 'Водниково', 'Берестовец', 'Мироярово',
#        'Тихолесье', 'Медвежанск', 'Каменичи', 'Лесиново', 'Тихогорово',
#        'Зелёнаярово', 'Синегориново', 'Лесозерск', 'Солнечеполье',
#        'Солнечеводск', 'Лесогорич', 'Ключевогорск', 'Нивинск',
#        'Травогорск', 'Шынгысай', 'Лесоярка', 'Луговское', 'Горноставинск',
#        'Зоречанск', 'Ручейновинск', 'Лесодолинск', 'Поленовец', 'Крутово',
#        'Зеленополье', 'Тепляковск', 'Желкаин', 'Березиноск',
#        'Горнополянск', 'Песчанская', 'Светополь', 'Поленоград',
#        'Вишнёвогорск', 'Северогорск', 'Речное', 'Каменевск', 'Травянский',
#        'Глинозорь', 'Луговинец', 'Серебровка', 'Горяново', 'Медовецк',
#        'Каменозолото', 'Желтоксан', 'Ясногорец', 'Горицветск',
#        'Ясносветск', 'Сосновинск', 'Белоярск', 'Солнечейск', 'Каменояр',
#        'Зеленолесье', 'Нуртас', 'Светогория', 'Беловодск', 'Малиновинск',
#        'Серебринск', 'Ключевинск', 'Тихозорин', 'Голубино', 'Долиновка',
#        'Шалкартау', 'Миросветск', 'Травяниково', 'Ясноград',
#        'Светочистенск', 'Кумсары', 'Зеленоградовск', 'Поленосветск',
#        'Каменодолин', 'Вишнёводск', 'Северобережье', 'Светозёринск',
#        'Каражар', 'Горнополёк', 'Ключезолотск', 'Горнолуг', 'Песчанец',
#        'Бережанка', 'Соловьёвка', 'Крутоводск', 'Бозарык', 'Родничанск',
#        'Берёзодальн', 'Озёречин', 'Поленосвет', 'Зоревичск', 'Коксуйск',
#        'Златоречинск', 'Жетисайск', 'Акжолтау', 'Байтерековск',
#        'Сереброяр', 'Яблоневое', 'Лесинск', 'Речинск', 'Яснополянск',
#        'Заречнинск', 'Речиноград', 'Радужнаярова', 'Светозорск',
#        'Горнополяровск', 'Речепольск', 'Тиходеревск', 'Ягодиноград',
#        'Желтау', 'Поленовичи', 'Тулебайск', 'Златоозёрово', 'Сарыбулак',
#        'Кристальевка', 'Сосновогорск', 'Теплоград', 'Яблоневск',
#        'Реченск', 'Бурьяново', 'Островозёров', 'Солнечёвино',
#        'Берёзоречье', 'Ветеринск', 'Тихолесьевск', 'Зореполин',
#        'Тихоозёрск', 'Родинсветск', 'Медвежник', 'Ясновский',
#        'Заречнаярово', 'Светоярич', 'Ручейницк', 'Лесогорский',
#        'Зелёново', 'Крутоводинск', 'Яснолесье', 'Солнечелесье', 'Луновка',
#        'Мироград', 'Светлоярск', 'Североград', 'Медвежиновск',
#        'Сосновецк', 'Зеленополин', 'Каражол', 'Заречка', 'Глинореч',
#        'Каменевский', 'Берёзогорск', 'Светозолотск', 'Гореловск',
#        'Малиновочист', 'Островской', 'Каменогорье', 'Чистояр', 'Ташбулак',
#        'Бережанск', 'Кристалин', 'Зареченец', 'Талдысай', 'Ягодино',
#        'Синеполинск', 'Берестяград', 'Алтынсай', 'Заречийск',
#        'Берёзополье', 'Зеленополец', 'Шынартас', 'Радужновка',
#        'Поленолесье', 'Златоречье', 'Островсков', 'Тогусжол',
#        'Светоречин', 'Айкольск', 'Радужовинск', 'Айсуак', 'Заречник',
#        'Глинолес', 'Зелёнояр', 'Синегорск', 'Каменогорский', 'Полянск',
#        'Крутовичи', 'Глинозолото', 'Ягодинска', 'Верховка', 'Тепляровск',
#        'Реченогор', 'Озёроярск', 'Тастай', 'Светоярово', 'Верхозорье',
#        'Поляноречинск', 'Малиновецк', 'Острововск', 'Светочистка',
#        'Долиновск', 'Мирополь', 'Озёряновск', 'Златополье', 'Кристаловка',
#        'Берёзореч', 'Зеленогорье', 'Солнечеград', 'Голубевск',
#        'Глинополянск', 'Радугорь', 'Кристолесье', 'Березиногорск',
#        'Миролесье', 'Заречинск', 'Ягодиноск', 'Байсары', 'Берёзиново',
#        'Солнечегорск', 'Глинополин', 'Озёроград', 'Ягодинец', 'Алтынкала',
#        'Горнолесье', 'Карасуй', 'Лесополин', 'Дальнеград', 'Горноград',
#        'Березовцево', 'Берёзовка', 'Дальнозелен', 'Травино', 'Карасуйск',
#        'Кызылжол', 'Поляновск', 'Лесогорск'], dtype=object)}

# %%
boxplot = df.boxplot(column='tickets_count', grid = False, figsize=(12, 10))
boxplot.set_title('Распределение количества билетов')
boxplot.set_xlabel('Количество билетов')
plt.show()

# %%
boxplot = df.boxplot(column='revenue_rub', grid = False, figsize=(12, 10))
boxplot.set_title('Распределение выручки')
boxplot.set_xlabel('Выручка (руб)')
plt.show()

# %%
df['revenue_rub'].hist(bins=20)
plt.show()

# %%
outliers = df['revenue_rub'].quantile(0.99)
new_df = df.loc[df['revenue_rub'] < outliers]
new_df['revenue_rub'].describe()
# Out:
# count    287604.000000
# mean        516.693737
# std         509.364882
# min         -90.760000
# 25%         111.675000
# 50%         343.620000
# 75%         787.710000
# max        2627.000000
# Name: revenue_rub, dtype: float64

# %%
new_df['tickets_count'].describe()
# Out:
# count    287604.000000
# mean          2.740330
# std           1.163422
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max          57.000000
# Name: tickets_count, dtype: float64

# %%
delited_rows = len(df) - len(new_df)
print (f'Количество удаленных строк: {delited_rows}')
print (f'Количество строк в новом датафрейме: {len(new_df)}')
# Out:
# Количество удаленных строк: 3007
# Количество строк в новом датафрейме: 287604

# %% [markdown]
# В ходе предобработки данных были проделаны следующие шаги и установлено следующее:
# - пропуски обнаружены только в столбце days_since_prev, что не является аномалией и не требует обработки, поскольку наличие пропусков по данному столбцу свиделельствует о том, что клиенты сделали всего один заказ;
# - сокращена размерность числовых данных;
# - выведены уникальные значения столбцов с номинальными данными. Столбец event_type_main содержит категорию 'другое', что может говорить об отсутствии информации о проводимом мероприятии, поскольку его не удалось категоризировать;
# - изучены разбросы данных по столбцам tickets_count и revenue_rub. Обнаружены выбросы с аномально высокими показателями выручки. Произведен срез по 99 перцентилю. В результате было удалено 3007 строк;
# - были обнаружены отрицательные значения в поле revenue_rub, что может говорить о возврате денежных средств. Было принято решение оставить отрицательные показатели, поскольку при возврате денежных средств клиенту, доход агенства уменшается на данную сумму и при необходимости дальнейших расчетов это также будет учтено;
# - количество строк в новом датафрейме : 287604.

# %% [markdown]
# ### ***3) Создание профиля пользователя***

# %%
df_new = df.sort_values(by='order_ts')
df_new.head()
# Out:
#                 user_id device_type_canonical  order_id   order_dt  \
# 285281  fd4d47438ebb946                mobile   7565637 2024-06-01
# 285282  fd4d47438ebb946                mobile   7565521 2024-06-01
# 118843  57ef0a1905ac488                mobile   6670842 2024-06-01
# 285279  fd4d47438ebb946                mobile   7565550 2024-06-01
# 264550  e73089d7d016cd8                mobile   5502055 2024-06-01
#
#                   order_ts currency_code  revenue  tickets_count  \
# 285281 2024-06-01 00:00:42           rub  1083.15              4
# 285282 2024-06-01 00:01:30           rub   812.36              3
# 118843 2024-06-01 00:01:58           rub  2091.31              4
# 285279 2024-06-01 00:03:13           rub   812.36              3
# 264550 2024-06-01 00:03:34           rub   181.39              2
#
#         days_since_prev  event_id                            event_name  \
# 285281              0.0    131671  f4431442-3d97-452d-a6d6-eadf6bd34378
# 285282              0.0    131671  f4431442-3d97-452d-a6d6-eadf6bd34378
# 118843              NaN    375861  ba89f19f-e73c-4d74-ab35-b9c023bb4de6
# 285279              NaN    131671  f4431442-3d97-452d-a6d6-eadf6bd34378
# 264550              0.0    211846  20165b73-7202-48df-a5e3-fd8cd1a70554
#
#          service_name event_type_main          region_name     city_name  \
# 285281      Прачечная           театр   Каменевский регион    Глиногорск
# 285282      Прачечная           театр   Каменевский регион    Глиногорск
# 118843  Билеты в руки           театр     Лесодальний край    Родниковец
# 285279      Прачечная           театр   Каменевский регион    Глиногорск
# 264550      Прачечная           театр  Широковская область  Радужнополье
#
#         revenue_rub
# 285281      1083.15
# 285282       812.36
# 118843      2091.31
# 285279       812.36
# 264550       181.39

# %%
first_last = df.groupby('user_id')['order_ts'].agg(['min', 'max']).reset_index()
first_last.rename(columns={'min' : 'first_order', 'max' : 'last_order'}, inplace = True)
idx_first_order = df.groupby('user_id')['order_ts'].idxmin()
first_orders = df.loc[idx_first_order].set_index('user_id')
profile = first_last.set_index('user_id').join(first_orders[['device_type_canonical', 'region_name', 'service_name', 'event_type_main']])
total_orders = df.groupby('user_id')['order_id'].count()
avg_revenue = df.groupby('user_id')['revenue_rub'].mean()
avg_tickets = round(df.groupby('user_id')['tickets_count'].mean(), 2)
def mean_time(group):
    delta = group['order_ts'].diff().dropna()
    if len(delta) > 0:
        return delta.mean()
    else:
        return pd.NaT
time_between_orders = df.groupby('user_id').apply(mean_time).reset_index(name='avg_time_between_orders')
profile = profile.join(total_orders.rename('total_orders'))
profile = profile.join(avg_revenue.rename('avg_revenue'))
profile = profile.join(avg_tickets.rename('avg_tickets'))
profile = profile.join(time_between_orders.set_index('user_id'))
profile.head()
# Out:
# /var/folders/7n/zg5fm9s55kqbwmn7nv4fqnw40000gn/T/ipykernel_50559/1555458335.py:15: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   time_between_orders = df.groupby('user_id').apply(mean_time).reset_index(name='avg_time_between_orders')
#                         first_order          last_order device_type_canonical  \
# user_id
# 0002849b70a3ce2 2024-08-20 16:08:03 2024-08-20 16:08:03                mobile
# 0005ca5e93f2cf4 2024-07-23 18:36:24 2024-10-06 13:56:02                mobile
# 000898990054619 2024-07-13 19:40:48 2024-10-23 15:12:00                mobile
# 00096d1f542ab2b 2024-08-15 16:48:48 2024-08-15 16:48:48               desktop
# 000a55a418c128c 2024-09-29 19:39:12 2024-10-15 10:29:04                mobile
#
#                           region_name   service_name event_type_main  \
# user_id
# 0002849b70a3ce2    Каменевский регион   Край билетов           театр
# 0005ca5e93f2cf4    Каменевский регион      Мой билет        выставки
# 000898990054619  Североярская область    Лови билет!          другое
# 00096d1f542ab2b    Каменевский регион   Край билетов           театр
# 000a55a418c128c      Поленовский край  Лучшие билеты           театр
#
#                  total_orders  avg_revenue  avg_tickets  \
# user_id
# 0002849b70a3ce2             1  1521.940000         4.00
# 0005ca5e93f2cf4             2   774.010000         3.00
# 000898990054619             3   767.213333         2.67
# 00096d1f542ab2b             1   917.830000         4.00
# 000a55a418c128c             2    61.310000         1.50
#
#                 avg_time_between_orders
# user_id
# 0002849b70a3ce2                     NaT
# 0005ca5e93f2cf4        74 days 19:19:38
# 000898990054619        50 days 21:45:36
# 00096d1f542ab2b                     NaT
# 000a55a418c128c        15 days 14:49:52

# %%
first_last = df.groupby('user_id')['order_ts'].agg(['min', 'max']).reset_index()
first_last.rename(columns={'min' : 'first_order', 'max' : 'last_order'}, inplace = True)
idx_first_order = df.groupby('user_id')['order_ts'].idxmin()
first_orders = df.loc[idx_first_order].set_index('user_id')
profile = first_last.set_index('user_id').join(first_orders[['device_type_canonical', 'region_name', 'service_name', 'event_type_main']])
total_orders = df.groupby('user_id')['order_id'].count()
avg_revenue = df.groupby('user_id')['revenue_rub'].mean()
avg_tickets = round(df.groupby('user_id')['tickets_count'].mean(), 2)
def mean_time(group):
    delta = group['order_ts'].diff().dropna()
    if len(delta) > 0:
        return delta.mean()
    else:
        return pd.NaT
time_between_orders = df.groupby('user_id').apply(mean_time).reset_index(name='avg_time_between_orders')
profile = profile.join(total_orders.rename('total_orders'))
profile = profile.join(avg_revenue.rename('avg_revenue'))
profile = profile.join(avg_tickets.rename('avg_tickets'))
profile = profile.join(time_between_orders.set_index('user_id'))
profile.head()
# Out:
# /var/folders/7n/zg5fm9s55kqbwmn7nv4fqnw40000gn/T/ipykernel_50559/1555458335.py:15: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   time_between_orders = df.groupby('user_id').apply(mean_time).reset_index(name='avg_time_between_orders')
#                         first_order          last_order device_type_canonical  \
# user_id
# 0002849b70a3ce2 2024-08-20 16:08:03 2024-08-20 16:08:03                mobile
# 0005ca5e93f2cf4 2024-07-23 18:36:24 2024-10-06 13:56:02                mobile
# 000898990054619 2024-07-13 19:40:48 2024-10-23 15:12:00                mobile
# 00096d1f542ab2b 2024-08-15 16:48:48 2024-08-15 16:48:48               desktop
# 000a55a418c128c 2024-09-29 19:39:12 2024-10-15 10:29:04                mobile
#
#                           region_name   service_name event_type_main  \
# user_id
# 0002849b70a3ce2    Каменевский регион   Край билетов           театр
# 0005ca5e93f2cf4    Каменевский регион      Мой билет        выставки
# 000898990054619  Североярская область    Лови билет!          другое
# 00096d1f542ab2b    Каменевский регион   Край билетов           театр
# 000a55a418c128c      Поленовский край  Лучшие билеты           театр
#
#                  total_orders  avg_revenue  avg_tickets  \
# user_id
# 0002849b70a3ce2             1  1521.940000         4.00
# 0005ca5e93f2cf4             2   774.010000         3.00
# 000898990054619             3   767.213333         2.67
# 00096d1f542ab2b             1   917.830000         4.00
# 000a55a418c128c             2    61.310000         1.50
#
#                 avg_time_between_orders
# user_id
# 0002849b70a3ce2                     NaT
# 0005ca5e93f2cf4        74 days 19:19:38
# 000898990054619        50 days 21:45:36
# 00096d1f542ab2b                     NaT
# 000a55a418c128c        15 days 14:49:52

# %%
profile['is_two'] = (total_orders >= 2).astype(int)
profile['is_five'] = (total_orders >= 5).astype(int)
profile.head()
# Out:
#                         first_order          last_order device_type_canonical  \
# user_id
# 0002849b70a3ce2 2024-08-20 16:08:03 2024-08-20 16:08:03                mobile
# 0005ca5e93f2cf4 2024-07-23 18:36:24 2024-10-06 13:56:02                mobile
# 000898990054619 2024-07-13 19:40:48 2024-10-23 15:12:00                mobile
# 00096d1f542ab2b 2024-08-15 16:48:48 2024-08-15 16:48:48               desktop
# 000a55a418c128c 2024-09-29 19:39:12 2024-10-15 10:29:04                mobile
#
#                           region_name   service_name event_type_main  \
# user_id
# 0002849b70a3ce2    Каменевский регион   Край билетов           театр
# 0005ca5e93f2cf4    Каменевский регион      Мой билет        выставки
# 000898990054619  Североярская область    Лови билет!          другое
# 00096d1f542ab2b    Каменевский регион   Край билетов           театр
# 000a55a418c128c      Поленовский край  Лучшие билеты           театр
#
#                  total_orders  avg_revenue  avg_tickets  \
# user_id
# 0002849b70a3ce2             1  1521.940000         4.00
# 0005ca5e93f2cf4             2   774.010000         3.00
# 000898990054619             3   767.213333         2.67
# 00096d1f542ab2b             1   917.830000         4.00
# 000a55a418c128c             2    61.310000         1.50
#
#                 avg_time_between_orders  is_two  is_five
# user_id
# 0002849b70a3ce2                     NaT       0        0
# 0005ca5e93f2cf4        74 days 19:19:38       1        0
# 000898990054619        50 days 21:45:36       1        0
# 00096d1f542ab2b                     NaT       0        0
# 000a55a418c128c        15 days 14:49:52       1        0

# %% [markdown]
# *Был построен новый датафрейм с данными о пользователях. Для этого данные были сгруппированы по пользователям и посчитаны такие показатели, как дата первого заказа, дата последнего заказа, тип устройства, с которого был сделан заказ, регион первого заказа, название сервиса, у которого был приобретен билет, тип мероприятия, количество заказов, средняя выручка, среднее количество билетов в заказе, среднее время между заказами, а также добовлены столбцы is_two — совершил ли пользователь 2 и более заказа и is_five — совершил ли пользователь 5 и более заказов.*

# %%
num_users = len(profile)
print (f'Количество пользователей в выборке : {num_users}')
# Out:
# Количество пользователей в выборке : 21933

# %%
sum_revenue = profile['avg_revenue'].sum()
all_orders = profile['total_orders'].sum()
avg_rev = round (sum_revenue / all_orders, 2)
print (f'Средняя выручка с одного заказа : {avg_rev}')
# Out:
# Средняя выручка с одного заказа : 43.32

# %%
mean_two = profile['is_two'].mean()
mean_five = profile['is_five'].mean()
print(f'Доля пользователей, совершивших 2 и более заказов : {round(mean_two, 2)}')
print(f'Доля пользователей, совершивших 5 и более заказов : {round(mean_five, 2)}')
# Out:
# Доля пользователей, совершивших 2 и более заказов : 0.62
# Доля пользователей, совершивших 5 и более заказов : 0.29

# %%
profile['total_orders'].describe()
# Out:
# count    21933.000000
# mean        13.249943
# std        122.470535
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max      10251.000000
# Name: total_orders, dtype: float64

# %%
profile['avg_tickets'].describe()
# Out:
# count    21933.000000
# mean         2.755985
# std          0.920749
# min          1.000000
# 25%          2.000000
# 50%          2.760000
# 75%          3.120000
# max         12.000000
# Name: avg_tickets, dtype: float64

# %%
profile['avg_tickets'] = profile['avg_tickets'].round().astype(int)
profile['avg_tickets'].describe()
# Out:
# count    21933.000000
# mean         2.758537
# std          0.954348
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          3.000000
# max         12.000000
# Name: avg_tickets, dtype: float64

# %%
profile['avg_time_between_orders'].describe()
# Out:
# count                         13559
# mean     15 days 19:18:05.719220808
# std      22 days 06:01:11.109399347
# min               -1 days +03:10:38
# 25%       1 days 00:15:33.229452054
# 50%                 8 days 02:12:25
# 75%         20 days 08:48:47.100000
# max               148 days 05:27:58
# Name: avg_time_between_orders, dtype: object

# %%
out = profile['total_orders'].quantile(0.99)
new_profile = profile.loc[profile['total_orders'] < out]
new_profile['total_orders'].describe()
# Out:
# count    21712.000000
# mean         6.508290
# std         14.268477
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max        151.000000
# Name: total_orders, dtype: float64

# %%
delited = len(profile) - len(new_profile)
print (f'Количество удаленных строк: {delited}')
print (f'Количество строк в новом датафрейме: {len(new_profile)}')
# Out:
# Количество удаленных строк: 221
# Количество строк в новом датафрейме: 21712

# %%
new_profile.info()
new_profile.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21712 entries, 0002849b70a3ce2 to ffff00725179321
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   first_order              21712 non-null  datetime64[ns]
#  1   last_order               21712 non-null  datetime64[ns]
#  2   device_type_canonical    21712 non-null  object
#  3   region_name              21712 non-null  object
#  4   service_name             21712 non-null  object
#  5   event_type_main          21712 non-null  object
#  6   total_orders             21712 non-null  int64
#  7   avg_revenue              21712 non-null  float64
#  8   avg_tickets              21712 non-null  int64
#  9   avg_time_between_orders  13338 non-null  timedelta64[ns]
#  10  is_two                   21712 non-null  int64
#  11  is_five                  21712 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(4), object(4), timedelta64[ns](1)
# memory usage: 2.2+ MB
#                          first_order                     last_order  \
# count                          21712                          21712
# mean   2024-08-11 04:11:34.001658112  2024-09-18 12:38:16.551538432
# min              2024-06-01 00:01:58            2024-06-01 01:29:40
# 25%    2024-06-26 13:53:22.750000128            2024-08-24 16:31:13
# 50%       2024-08-09 20:42:46.500000            2024-10-02 21:57:27
# 75%    2024-09-23 13:16:34.750000128            2024-10-22 13:13:56
# max              2024-10-31 23:55:27            2024-10-31 23:59:54
# std                              NaN                            NaN
#
#        total_orders   avg_revenue   avg_tickets     avg_time_between_orders  \
# count  21712.000000  21712.000000  21712.000000                       13338
# mean       6.508290    574.258942      2.756494  16 days 01:23:57.059233877
# min        1.000000    -10.770000      1.000000           -1 days +03:10:38
# 25%        1.000000    212.285000      2.000000      1 days 07:58:27.421875
# 50%        2.000000    472.091500      3.000000      8 days 09:13:22.450000
# 75%        5.000000    788.343333      3.000000     20 days 17:39:56.900000
# max      151.000000  16738.696667     12.000000           148 days 05:27:58
# std       14.268477    560.299903      0.958721  22 days 08:18:09.559287362
#
#              is_two       is_five
# count  21712.000000  21712.000000
# mean       0.614315      0.284589
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        1.000000      0.000000
# 75%        1.000000      1.000000
# max        1.000000      1.000000
# std        0.486768      0.451229

# %% [markdown]
# **В ходе предварительного анализа данных были изучены основные статистические показатели, а также удалено определенное количество строк.
# Столбец данных, отражающих количество совершенных пользователем заказов имел максимальным значением 10251 заказ, что явно не может соответствовать действительности и является выбросом. Было принято решение отфильтровать данные по 99 перцентилю для исключения из анализа такого рода данных.
# Также было установлено, что столбец со средним количеством билетов был представлен в типе float. Учитывая специфику такого рода данных (количество билетов не может быть представлено числом с дробной частью), было принято решение о приведении к типу данных int с округлением до ближайшего целого числа.
# После проведенной фильтрации по количеству билетов был создан обновленный датасет new_profile с исключенными из него выбросами.**

# %% [markdown]
# ### ***4) Исследовательский анализ данных***

# %%
new_profile = new_profile.reset_index() 
event_type = new_profile.groupby('event_type_main')['user_id'].count()
print(event_type.sort_values(), 
      event_type.sort_values() / len(new_profile))
# Out:
# event_type_main
# ёлки          95
# выставки     410
# спорт        797
# стендап     1109
# театр       4261
# другое      5425
# концерты    9615
# Name: user_id, dtype: int64 event_type_main
# ёлки        0.004375
# выставки    0.018884
# спорт       0.036708
# стендап     0.051078
# театр       0.196251
# другое      0.249862
# концерты    0.442843
# Name: user_id, dtype: float64

# %%
device_type = new_profile.groupby('device_type_canonical')['user_id'].count()
print(device_type, 
      device_type / len(new_profile))
# Out:
# device_type_canonical
# desktop     3737
# mobile     17975
# Name: user_id, dtype: int64 device_type_canonical
# desktop    0.172117
# mobile     0.827883
# Name: user_id, dtype: float64

# %%
region_type = new_profile.groupby('region_name')['user_id'].count()
print(region_type.sort_values(), 
      region_type.sort_values() / len(new_profile))
# Out:
# region_name
# Верхозёрский край              1
# Сосноводолинская область       1
# Яснопольский округ             1
# Залесский край                 2
# Светолесский край              2
#                             ...
# Малиновоярский округ         532
# Озернинский край             676
# Широковская область         1231
# Североярская область        3761
# Каменевский регион          7134
# Name: user_id, Length: 81, dtype: int64 region_name
# Верхозёрский край           0.000046
# Сосноводолинская область    0.000046
# Яснопольский округ          0.000046
# Залесский край              0.000092
# Светолесский край           0.000092
#                               ...
# Малиновоярский округ        0.024503
# Озернинский край            0.031135
# Широковская область         0.056697
# Североярская область        0.173222
# Каменевский регион          0.328574
# Name: user_id, Length: 81, dtype: float64

# %%
service_type = new_profile.groupby('service_name')['user_id'].count()
print(service_type.sort_values(), 
      service_type.sort_values() / len(new_profile))
# Out:
# service_name
# Зе Бест!                     1
# Лимоны                       2
# Тех билет                    3
# Билет по телефону            6
# Вперёд!                      7
# Кино билет                   9
# КарандашРУ                  15
# Шоу начинается!             20
# Цвет и билет                23
# Телебилет                   27
# Реестр                      32
# Радио ticket                36
# Crazy ticket!               45
# Росбилет                    52
# Быстрый кассир              59
# Восьмёрка                   86
# Выступления.ру              97
# Быстробилет                163
# Show_ticket                165
# За билетом!                203
# Мир касс                   205
# Городской дом культуры     216
# Тебе билет!                308
# Яблоко                     318
# Дом культуры               353
# Край билетов               457
# Прачечная                  586
# Лучшие билеты             1182
# Весь в билетах            1301
# Облачко                   2178
# Билеты в руки             2551
# Лови билет!               2814
# Мой билет                 2998
# Билеты без проблем        5194
# Name: user_id, dtype: int64 service_name
# Зе Бест!                  0.000046
# Лимоны                    0.000092
# Тех билет                 0.000138
# Билет по телефону         0.000276
# Вперёд!                   0.000322
# Кино билет                0.000415
# КарандашРУ                0.000691
# Шоу начинается!           0.000921
# Цвет и билет              0.001059
# Телебилет                 0.001244
# Реестр                    0.001474
# Радио ticket              0.001658
# Crazy ticket!             0.002073
# Росбилет                  0.002395
# Быстрый кассир            0.002717
# Восьмёрка                 0.003961
# Выступления.ру            0.004468
# Быстробилет               0.007507
# Show_ticket               0.007599
# За билетом!               0.009350
# Мир касс                  0.009442
# Городской дом культуры    0.009948
# Тебе билет!               0.014186
# Яблоко                    0.014646
# Дом культуры              0.016258
# Край билетов              0.021048
# Прачечная                 0.026990
# Лучшие билеты             0.054440
# Весь в билетах            0.059921
# Облачко                   0.100313
# Билеты в руки             0.117493
# Лови билет!               0.129606
# Мой билет                 0.138080
# Билеты без проблем        0.239223
# Name: user_id, dtype: float64

# %% [markdown]
# В ходе проведенного сегментирования пользователей было установлено следующее:
# - порядка 44 процентов первых посещений приходится на концерты, минимальное количество первых посещений у мероприятий елки (что объяснимо спецификой самого мероприятия);
# - более 80 процентов первых заказов были сделаны через мобильный телефон;
# - порядка 30 процентов посещений первых мероприятий приходится на жителей Каменевского района, однако, без дополнительных данных о плотности населения и наличии развлекательных площадок в том или ином регионе проблематично делать выводы о специфики такой сегментации;
# - билетный оператор с максимальным количеством первых обращений - Билеты без проблем (порядка 23 процентов). Еще 4 оператора имеют показатели порядка 10 процентов. У остальных этот показатель менее 5 процентов.
#
# Таким образом, можно сделать вывод о том, что наиболее часто встречающийся тип клиента - житель Каменевского района, посещающий концерты. Для дополнительной информации необходим дальнейший углубленный анализ.

# %%
is_two_profile = new_profile[new_profile['is_two'] == 1].copy()
event_pro = is_two_profile.groupby('event_type_main')['user_id'].count().sort_values()
event_pro.plot(kind = 'bar',
               title = 'Распределение доли популярности мероприятий',
               ylabel = 'Количество посещений',
               legend = False,
               rot = 45,
               figsize=(10, 8))
print(event_pro.sort_values() / len(is_two_profile))
plt.show()
# Out:
# event_type_main
# ёлки        0.003899
# выставки    0.019568
# спорт       0.033363
# стендап     0.050457
# театр       0.202729
# другое      0.242615
# концерты    0.447368
# Name: user_id, dtype: float64

# %%
device_pro = is_two_profile.groupby('device_type_canonical')['user_id'].count()
print(device_pro / len(is_two_profile))
# Out:
# device_type_canonical
# desktop    0.179037
# mobile     0.820963
# Name: user_id, dtype: float64

# %% [markdown]
# Предполагаю, что для двух показателей с настолько большой разницей, визуализация была бы излишней.

# %%
region_pro = is_two_profile.groupby('region_name')['user_id'].count().sort_values(ascending=False).head(10)
region_pro.plot(kind = 'bar',
               title = 'Распределение клиентов по регионам',
               ylabel = 'Количество',
               legend = False,
               rot = 45,
               figsize=(10, 8))
print(region_pro / len(is_two_profile))
plt.show()
# Out:
# region_name
# Каменевский регион      0.334083
# Североярская область    0.180237
# Широковская область     0.059754
# Озернинский край        0.027890
# Шанырский регион        0.025941
# Светополянский округ    0.022792
# Травяная область        0.022567
# Малиновоярский округ    0.022417
# Речиновская область     0.020768
# Яблоневская область     0.018444
# Name: user_id, dtype: float64

# %%
service_pro = is_two_profile.groupby('service_name')['user_id'].count().sort_values(ascending=False).head(10)
service_pro.plot(kind = 'bar',
               title = 'Распределение клиентов по сервисам',
               ylabel = 'Количество',
               legend = False,
               rot = 45,
               figsize=(10, 8))
print(service_pro / len(is_two_profile))
plt.show()
# Out:
# service_name
# Билеты без проблем    0.235643
# Мой билет             0.137277
# Лови билет!           0.128880
# Билеты в руки         0.119883
# Облачко               0.100240
# Весь в билетах        0.061553
# Лучшие билеты         0.054281
# Прачечная             0.027515
# Край билетов          0.022342
# Дом культуры          0.017094
# Name: user_id, dtype: float64

# %% [markdown]
# По результатам анализа можно сказать следующее:
# - чаще всего возвращаются пользователи, у которых первым посещением был концерт;
# - также возвращаются пользователи, совершившие первый заказ посредством мобильного телефона;
# - наиболее активная часть клиентов сосредоточена в Каменевском районе и Североярской области (33 и 18 процентов соответственно);
# - наиболее популярный сервис заказа билетов - Билеты без проблем.

# %%
sport_orders = new_profile[new_profile['event_type_main'] == 'спорт']
concert_orders = new_profile[new_profile['event_type_main'] == 'концерты']

total_sport_users = sport_orders['user_id'].nunique()
repeat_sport_users = sport_orders[sport_orders['is_two'] == 1]['user_id'].nunique()
sport_rate = (repeat_sport_users / total_sport_users * 100) if total_sport_users else 0

total_concert_users = concert_orders['user_id'].nunique()
repeat_concert_users = concert_orders[concert_orders['is_two'] == 1]['user_id'].nunique()
concert_rate = (repeat_concert_users / total_concert_users * 100) if total_concert_users else 0

print(f"Процент возврата пользователей, впервые поситивших спорт: {sport_rate:.2f}%")
print(f"Процент возврата пользователей, впервые поситивших концерт: {concert_rate:.2f}%")
# Out:
# Процент возврата пользователей, впервые поситивших спорт: 55.83%
# Процент возврата пользователей, впервые поситивших концерт: 62.06%

# %% [markdown]
# **Первая гипотеза не нашла подтверждения при проверке. Процент пользователей, впервые поситивших концерт, выше, чем процент тех, кто впервые посетил спортивное мероприятие.**

# %%
regional_counts = new_profile.groupby('region_name')['user_id'].nunique().reset_index()
top_regions = regional_counts.sort_values(by='user_id', ascending=False).head(5)
bottom_regions = regional_counts.sort_values(by='user_id', ascending=True).head(5)
top_heart = new_profile[new_profile['region_name'].isin(top_regions['region_name'])]
bottom_heart = new_profile[new_profile['region_name'].isin(bottom_regions['region_name'])]
def calculate_repeat_rate(new_profile):
    total_users = new_profile['user_id'].nunique()
    repeat_users = new_profile[new_profile['is_two'] == 1]['user_id'].nunique()
    return (repeat_users / total_users * 100) if total_users else 0

top_rate = calculate_repeat_rate(top_heart)
bottom_rate = calculate_repeat_rate(bottom_heart)

print(f"Процент повторных заказов в топ-5 регионах: {top_rate:.2f}%")
print(f"Процент повторных заказов в низших регионах: {bottom_rate:.2f}%")
# Out:
# Процент повторных заказов в топ-5 регионах: 62.46%
# Процент повторных заказов в низших регионах: 42.86%

# %% [markdown]
# **Вторая гипотеза нашла свое подтверждение в ходе проверки. Действительно, пользователи из более активных регионов чаще делают повторный заказ на платформе.**

# %%
avg_service = new_profile.groupby('service_name')['avg_revenue'].sum().sort_values()
order_counts = new_profile.groupby('service_name')['total_orders'].count().sort_values()
avg_service_per_order = avg_service / order_counts
print(avg_service_per_order.sort_values())
# Out:
# service_name
# Зе Бест!                    16.166667
# Лучшие билеты              262.817358
# КарандашРУ                 295.674544
# Радио ticket               336.449572
# Кино билет                 359.043035
# Вперёд!                    368.255143
# Билеты в руки              429.819126
# Тех билет                  432.102222
# Лимоны                     441.663750
# Лови билет!                469.409090
# Билеты без проблем         481.635526
# Реестр                     525.526897
# Прачечная                  526.613084
# Crazy ticket!              583.563005
# Тебе билет!                621.691816
# Телебилет                  629.063919
# Городской дом культуры     642.492205
# Восьмёрка                  655.703890
# Мой билет                  659.094348
# Облачко                    677.746182
# За билетом!                706.966445
# Яблоко                     718.755025
# Быстробилет                742.214703
# Выступления.ру             785.469578
# Быстрый кассир             792.483173
# Билет по телефону          794.755556
# Мир касс                   811.693798
# Цвет и билет               813.647496
# Show_ticket                864.429831
# Весь в билетах             918.736095
# Дом культуры               919.915674
# Край билетов               946.504418
# Росбилет                  1456.423037
# Шоу начинается!           1494.729348
# dtype: float64

# %%
mode_value = new_profile['avg_tickets'].mode()[0]
print(f'Мода среднего количества билетов : {mode_value}')
# Out:
# Мода среднего количества билетов : 3

# %%
sns.histplot(data=new_profile, x='avg_revenue', hue='is_two',
             element='step', stat='count',
             common_norm=False, alpha=0.5)

plt.xlabel('Средняя выручка с билета')
plt.title('Распределение средней выручки по группам')
plt.legend(['1 заказ', '2 и более заказов'])
plt.show()

# %% [markdown]
# Данный график сложно воспринимать из-за особенностей распределения данных. Для полноты картины ограничим xlabel 3000.

# %%
sns.histplot(data=new_profile, x='avg_revenue', kde=True, hue='is_two')
plt.title('Распределение средней выручки в зависимости от повторности заказа')
plt.xlabel('Средняя выручка с билета (руб.)')
plt.ylabel('Количество заказов')
plt.legend(['1 заказ', '2 и более заказов'])
plt.xlim(0, 3000)
plt.show()

# %% [markdown]
# **Большинство данных лежит в диапазоне от 0 до 1500 рублей. Наблюдая данный график, можно сделать вывод о том, что наибольшую среднюю выручку приносили клиенты, делавшие 1 заказ, в то время как пользователи с повторыми заказами приносили меньше средней выручки. Из этого можно сделать следующий вывод: клиенты, возможно, не возвращаются из-за высоких цен на билеты.**

# %%
def assign_category(row):
    if row['is_five'] == 1:
        return '5 и более билетов'
    elif row['is_two'] == 1 and row['is_five'] == 0:
        return '2-4 билета'
new_profile['ticket_category'] = new_profile.apply(assign_category, axis=1)
sns.boxplot(x='ticket_category', y='avg_revenue', data=new_profile, order=['2-4 билета', '5 и более билетов'])
plt.xlabel('Категория количества билетов')
plt.ylabel('Средняя выручка')
plt.title('Распределение средней выручки по категориям')
plt.ylim(0, 5000)
plt.show()

# %% [markdown]
# **В ходе изучения влияния количества билетов на среднюю выручку было установлено следующее: у тех клиентов, которые имеют более 5 билетов, распределение средней выручки смещено в наименьшую сторону, по сравнению с тем, у кого 2 - 4 билета. Данный факт - еще одно подтверждение того, что возвращаются пользователи, кто платит меньше за билеты.**

# %%
sns.histplot(new_profile['avg_tickets'], bins=10, kde=False)
plt.xlabel('Среднее количество билетов в заказе')
plt.ylabel('Количество')
plt.title('Распределение среднего количества билетов в заказе')
plt.show()

# %% [markdown]
# **Результаты данного графика легко интерпретировать и объяснить тем, что большинство пользователей покупают билеты на меропрятия в личных нуждах и, как правило, такое количество ограничивается 1-4 билетов за 1 заказ.**

# %%
def assign_segment(row):
    if row['avg_tickets'] >= 1 and row['avg_tickets'] < 2:
        return '1-2 билета'
    elif row['avg_tickets'] >= 2 and row['avg_tickets'] < 3:
        return '2-3 билета'
    elif row['avg_tickets'] >= 3 and row['avg_tickets'] < 5:
        return '3-5 билетов'
    else:
        return '5 и более билетов'
new_profile['ticket_segment'] = new_profile.apply(assign_segment, axis=1)
segment_counts = new_profile.groupby('ticket_segment')['user_id'].nunique()
repeat_order_stats = new_profile.groupby('ticket_segment')['is_two'].mean()
result = pd.DataFrame({
    'Количество пользователей': segment_counts,
    'Доля повторных заказов': repeat_order_stats
})
print(result)
# Out:
#                    Количество пользователей  Доля повторных заказов
# ticket_segment
# 1-2 билета                             1455                0.194502
# 2-3 билета                             7636                0.672996
# 3-5 билетов                           11872                0.650522
# 5 и более билетов                       749                0.257677

# %% [markdown]
# **В ходе проведенной сегментации пользователей было установлено следующее: наибольшее количество пользователей имеет 3 - 5 билетов в заказе (более 11000), в то время как более 5 билетов в заказе имеют менее 1000 пользователей. С долей повторных заказов ситуация схожая: более 60 процентов возвращающихся пользователей находятся в сегментах 2-3 билета и 3-5 билетов. А наименьший процент возврата у пользователей в сегменте 1-2 билета.**

# %%
new_profile['day_of_week'] = new_profile['first_order'].dt.dayofweek
days_mapping = {
    0: 'Понедельник',
    1: 'Вторник',
    2: 'Среда',
    3: 'Четверг',
    4: 'Пятница',
    5: 'Суббота',
    6: 'Воскресенье'
}
new_profile['day_name'] = new_profile['day_of_week'].map(days_mapping)
days_group = new_profile.groupby('day_name')['user_id'].count().sort_values()
days_repeat_group = new_profile.groupby('day_name')['is_two'].mean().sort_values()
days_group.plot(kind='bar')
plt.show()

# %% [markdown]
# **Согласно данному графику, день недели не имеет сильного влияния на покупку билета, однако в пятницу и субботу данный показатель чуть выше, чем в остальные дни недели.**

# %%
group1 = new_profile[new_profile['total_orders'].between(2, 4)]
group2 = new_profile[new_profile['total_orders'] >= 5]
avg_time_group1 = group1['avg_time_between_orders'].mean()
avg_time_group2 = group2['avg_time_between_orders'].mean()
print(f"Среднее время между заказами для пользователей, совершивших 2-4 заказа: {avg_time_group1}")
print(f"Среднее время между заказами для пользователей, совершивших более 5 заказов: {avg_time_group2}")
# Out:
# Среднее время между заказами для пользователей, совершивших 2-4 заказа: 21 days 07:40:48.060506588
# Среднее время между заказами для пользователей, совершивших более 5 заказов: 9 days 23:05:23.973279623

# %% [markdown]
# **Полученная частота покупки билетов объясняется вполне логично: чем больше заказов, тем меньше времени между ними, поскольку анализируется сравнительно небольшой промежуток времени.**

# %%
new_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21712 entries, 0 to 21711
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  21712 non-null  object
#  1   first_order              21712 non-null  datetime64[ns]
#  2   last_order               21712 non-null  datetime64[ns]
#  3   device_type_canonical    21712 non-null  object
#  4   region_name              21712 non-null  object
#  5   service_name             21712 non-null  object
#  6   event_type_main          21712 non-null  object
#  7   total_orders             21712 non-null  int64
#  8   avg_revenue              21712 non-null  float64
#  9   avg_tickets              21712 non-null  int64
#  10  avg_time_between_orders  13338 non-null  timedelta64[ns]
#  11  is_two                   21712 non-null  int64
#  12  is_five                  21712 non-null  int64
#  13  ticket_category          13338 non-null  object
#  14  ticket_segment           21712 non-null  object
#  15  day_of_week              21712 non-null  int32
#  16  day_name                 21712 non-null  object
# dtypes: datetime64[ns](2), float64(1), int32(1), int64(4), object(8), timedelta64[ns](1)
# memory usage: 2.7+ MB

# %% [markdown]
# *В датафреме к данному моменту помимо изначальных данных добавились данные по сегментациям, категориям и дням неделя. Для проведения корреляционного анализа указанные данные также могут пригодится.*

# %%
new_profile['days_between'] = new_profile['avg_time_between_orders'].dt.days
correlation_matrix = new_profile[['device_type_canonical', 'region_name', 'service_name', 'event_type_main', 'total_orders', 'days_between', 'day_name', 'ticket_segment']].phik_matrix(interval_cols=['days_between'])
correlation_matrix.loc[correlation_matrix.index != 'total_orders'][['total_orders']].sort_values(by='total_orders', ascending=False)
plt.figure(figsize=(2, 6))
data_heatmap = correlation_matrix.loc[correlation_matrix.index != 'total_orders'][['total_orders']].sort_values(by='total_orders', ascending=False)
sns.heatmap(data_heatmap,
            annot=True,
            fmt='.2f',
            cmap = 'coolwarm', 
            linewidths=0.5,
            cbar=False)
plt.title('Тепловая карта')
plt.show()

# %%
plt.hist(new_profile['total_orders'], bins=50)
plt.xlabel('Значения')
plt.ylabel('Частота')
plt.title('Гистограмма распределения значений total_orders')
plt.show()

# %%
def total_orders_category(row):
    if row['total_orders'] == 1:
        return '1 заказ'
    elif row['total_orders'] >= 2 and row['total_orders'] <= 4:
        return '2-4 заказа'
    elif row['total_orders'] >= 5:
        return 'более 5 заказов'
new_profile['orders_category'] = new_profile.apply(total_orders_category, axis=1)
correlation_matrix = new_profile[['device_type_canonical', 'region_name', 'service_name', 'event_type_main', 'orders_category', 'days_between', 'day_name', 'ticket_segment']].phik_matrix(interval_cols=['days_between'])
correlation_matrix.loc[correlation_matrix.index != 'orders_category'][['orders_category']].sort_values(by='orders_category')
plt.figure(figsize=(2, 6))
data_heatmap = correlation_matrix.loc[correlation_matrix.index != 'orders_category'][['orders_category']].sort_values(by='orders_category')
sns.heatmap(data_heatmap,
            annot=True,
            fmt='.2f',
            cmap = 'coolwarm', 
            linewidths=0.5,
            cbar=False)
plt.title('Тепловая карта')
plt.show()

# %% [markdown]
# **Сегментация заказов незначительно повлияла на связь с некоторыми категориями, однако в общей тенденции осталась неизменной. Наибольшая взаимосвязь (данную связь можно назвать умеренной) наблюдается с количеством билетов и днями между заказами, что вполне объяснимо интервалом времени, который включен в анализ данных. Также, если обратиться к первой тепловой карте, можно также наблюдать небольшую зависимость от региона и сегментации билетов в заказе.**

# %% [markdown]
# ### ***5) Общие выводы и рекомендации***

# %% [markdown]
# **Был произведен анализ данных Яндекс.Афиши. В первую очередь, из большого набора табличных данных были извлечены те столбцы, которые, с наибольшей долей вероятности, пригодились бы для дальнейшего анализа. Был составлен новый датафрейм для дальнейшей работы. В ходе изучения полученных данных также были выявлены некоторые особенности, которые требовали преобразования. Так, был образован новый столбец со стоимостью билетов в рублях (изначальный датафрейм содержал данных о стоимости в тенге и российских рублях, для дальнейшей работы целесообразно было привести все к единой валюте). Также изначальный датафрейм был сокращен за счет удаления аномальных значений количества билетов. Данные были отфильтрованы по 99 перцентилю и оставлены наиболее реальные данные по билетам. Также в данных были установлены отрицательные значения выручки, однако, было принято решение оставить эти значения, поскольку, они могли быть связаны с возвратами денежных средств за приобретенные билеты.
# Для анализа данных в выборку попало порядка 21000 записей за период времени 5 месяцев. Пользователи сегментизировались по различным основаниям (тип первого мероприятия, тип устройства совершения заказа, билетный оператор и район совершения заказа). Изучив полученные данные можно сделать вывод о том, что большинство пользователей совершают первые заказы на концерты (около 44 процентов), также заказы чаще всего делаются через мобильный телефон (более 80 процентов заказов). По району первого заказа лидирует Каменевский регион, а среди билетных операторов - Билеты без проблем.**
#
# **Чаще всего возвращаются пользователи, у которых первым посещением был концерт; также возвращаются пользователи, совершившие первый заказ посредством мобильного телефона; наиболее активная часть клиентов сосредоточена в Каменевском районе и Североярской области (33 и 18 процентов соответственно); наиболее популярный сервис заказа билетов - Билеты без проблем.**
#
# **Также наблюдалась интересная зависимость между средней выручкой и возвратом покупателей. Наиболее активная часть пользователей делали сравнительно меньшую выручку, чем тем, кто покупал билеты только один раз. Из этого следует вывод: возвращается та часть пользователей, которые приобрели билеты по сравнительно низким ценам. Те, кто сделали на сервисе один заказ обычно показывали повышенные показатели выручки.**
#
# **В ходе изучения влияния количества билетов на среднюю выручку было установлено следующее: у тех клиентов, которые имеют более 5 билетов, распределение средней выручки смещено в наименьшую сторону, по сравнению с тем, у кого 2 - 4 билета. Данный факт - еще одно подтверждение того, что возвращаются пользователи, кто платит меньше за билеты.**
#
# **Анализ дня недели, в который была совершена покупка, показал, что большая часть пользователей приобретают билеты в пятницу и субботу.**
#
# **Анализ интервалов между покупками показал довольно закономерный результат: чем больше заказом, тем меньше интервал между заказами.**
#
# **Также была составлена матрица корреляции. Корреляционный анализ показал, что наибольшая взаимосвязь с количеством билетов установлена у интервалов между покупками. Данное явление объяснено азбацем выше (чем больше билетом, тем меньше интервал между покупками). Также сравнительно небольшая корреляция наблюдалась с количеством билетов и регионом покупки. Однако без дополнительных данных по характеристикам регионов сложно сделать однозначный вывод о такой зависимости. Возможно, это может быть связано с плотностью населения в регионе и наличием мест под проведение мероприятий. Как правило, пользователи ищут места для развлечений недалеко от места проживания.**
#
# **В завершении имеются некоторые рекомендации, которые могут быть сделаны на основе проведенного анализа.**
#
# ***- С целью удержания клиентов, совершивших первый заказ, необходимо обратить внимание на систему скидок и бонусов, которые будут стимулировать пользователей вновь обращаться к сервису с целью поиска мероприятий;***
#
# ***- учитывая дни совершения покупок, можно рассмотреть ряд акций на покупку билетов в воскресенье и понедельник, т.к. в эти дни активность пользователей наименьшая;***
#
# ***- возможно, следует обратить внимание на систему бонусов в регионах, с наименьшим числом заказов.***

# %%
# !pwd
# Out:
# /Users/tatjana/Project_Git

# %%
# !touch .gitignore

# %%
# !ls -a
# Out:
# .                  .gitignore         .ipynb_checkpoints untitled.txt
# ..                 .gitignore.swp     Untitled.ipynb

# %%
# %%writefile .gitignore
# env/
# venv/
# *.env
# *.pyenv
# __pycache__/
# *.py[cod]
# .idea/
# .vscode/
# *.iml
# *.log
# *.bak
# *.swp
# .DS_Store
# Out:
# Overwriting .gitignore

# %%
# !pip freeze > requirements.txt

# %%
# %%writefile .env
# Хост — rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net
# База данных — data-analyst-afisha
# Порт — 6432
# Аутентификация — Database Native
# Пользователь — praktikum_student
# Пароль — Sdf4$2;d-d30pp
# Out:
# Writing .env
